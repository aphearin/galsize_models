# %%
# %matplotlib inline

# %%
import os
wp_dirname = "../../galsize_models/measurements/data/two_point_functions/"

rp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_rp.npy')
rp = np.load(rp_fname)

ifirst = np.searchsorted(rp, 0.15)

# %%
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_wp.npy')
sdss_sm10p0_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_wp.npy')
sdss_sm10p0_sf_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_gv_wp.npy')
sdss_sm10p0_gv_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_wp.npy')
sdss_sm10p0_q_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_bulge_dom_wp.npy')
sdss_sm10p0_meert15_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_disk_dom_wp.npy')
sdss_sm10p0_meert15_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_meert15_bulge_dom_wp.npy')
sdss_sm10p0_sf_meert15_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_meert15_disk_dom_wp.npy')
sdss_sm10p0_sf_meert15_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_gv_meert15_bulge_dom_wp.npy')
sdss_sm10p0_gv_meert15_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_gv_meert15_disk_dom_wp.npy')
sdss_sm10p0_gv_meert15_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_meert15_bulge_dom_wp.npy')
sdss_sm10p0_q_meert15_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_meert15_disk_dom_wp.npy')
sdss_sm10p0_q_meert15_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_mendel13_bulge_dom_wp.npy')
sdss_sm10p0_mendel13_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_mendel13_disk_dom_wp.npy')
sdss_sm10p0_mendel13_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_mendel13_bulge_dom_wp.npy')
sdss_sm10p0_sf_mendel13_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_mendel13_disk_dom_wp.npy')
sdss_sm10p0_sf_mendel13_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_mendel13_bulge_dom_wp.npy')
sdss_sm10p0_q_mendel13_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_mendel13_disk_dom_wp.npy')
sdss_sm10p0_q_mendel13_disk_dom_wp = np.load(_wp_fname)

# %%
fig, ax = plt.subplots(1, 1)

__=ax.loglog()

__=ax.plot(rp[ifirst:], sdss_sm10p0_q_wp[ifirst:], color='red', label='quenched')
__=ax.plot(rp[ifirst:], sdss_sm10p0_meert15_bulge_dom_wp[ifirst:], color='orange', label='bulge-dominated')

__=ax.plot(rp[ifirst:], sdss_sm10p0_wp[ifirst:], color='k', label='all galaxies')

__=ax.plot(rp[ifirst:], sdss_sm10p0_meert15_disk_dom_wp[ifirst:], color='purple', label='disk-dominated')
__=ax.plot(rp[ifirst:], sdss_sm10p0_sf_wp[ifirst:], color='blue', label='star-forming')

leg = ax.legend()

# %%
fig, ax = plt.subplots(1, 1)

__=ax.loglog()

__=ax.plot(rp[ifirst:], sdss_sm10p0_meert15_bulge_dom_wp[ifirst:], color='k', 
          label=r'Meert+15')
__=ax.plot(rp[ifirst:], sdss_sm10p0_mendel13_bulge_dom_wp[ifirst:], '--', color='k', 
          label=r'Mendel+13')


__=ax.plot(rp[ifirst:], sdss_sm10p0_meert15_bulge_dom_wp[ifirst:], color='orange', 
          label=r'bulge-dominated')
__=ax.plot(rp[ifirst:], sdss_sm10p0_mendel13_bulge_dom_wp[ifirst:], '--', color='orange')
__=ax.plot(rp[ifirst:], sdss_sm10p0_mendel13_disk_dom_wp[ifirst:], '--', color='purple')


__=ax.plot(rp[ifirst:], sdss_sm10p0_meert15_disk_dom_wp[ifirst:], color='purple', 
          label=r'disk-dominated')


title = ax.set_title(r'$M_{\ast} > 10^{10}M_{\odot}$')
xlabel = ax.set_xlabel(r'$r_{\rm p}$  $[{\rm Mpc}]$')
ylabel = ax.set_ylabel(r'$w_{\rm p}$  $[{\rm Mpc}]$')

leg = ax.legend()
leg.legendHandles[0].set_color('gray')
leg.legendHandles[1].set_color('gray')

# %%
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_wp.npy')
sdss_sm10p5_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_sf_wp.npy')
sdss_sm10p5_sf_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_q_wp.npy')
sdss_sm10p5_q_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_meert15_bulge_dom_wp.npy')
sdss_sm10p5_meert15_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_meert15_disk_dom_wp.npy')
sdss_sm10p5_meert15_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_sf_meert15_bulge_dom_wp.npy')
sdss_sm10p5_sf_meert15_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_sf_meert15_disk_dom_wp.npy')
sdss_sm10p5_sf_meert15_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_q_meert15_bulge_dom_wp.npy')
sdss_sm10p5_q_meert15_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_q_meert15_disk_dom_wp.npy')
sdss_sm10p5_q_meert15_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_mendel13_bulge_dom_wp.npy')
sdss_sm10p5_mendel13_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_mendel13_disk_dom_wp.npy')
sdss_sm10p5_mendel13_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_sf_mendel13_bulge_dom_wp.npy')
sdss_sm10p5_sf_mendel13_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_sf_mendel13_disk_dom_wp.npy')
sdss_sm10p5_sf_mendel13_disk_dom_wp = np.load(_wp_fname)

_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_q_mendel13_bulge_dom_wp.npy')
sdss_sm10p5_q_mendel13_bulge_dom_wp = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p5_q_mendel13_disk_dom_wp.npy')
sdss_sm10p5_q_mendel13_disk_dom_wp = np.load(_wp_fname)


fig, ax = plt.subplots(1, 1)

__=ax.loglog()

__=ax.plot(rp[ifirst:], sdss_sm10p5_meert15_bulge_dom_wp[ifirst:], color='k', 
          label=r'Meert+15')
__=ax.plot(rp[ifirst:], sdss_sm10p5_mendel13_bulge_dom_wp[ifirst:], '--', color='k', 
          label=r'Mendel+13')


__=ax.plot(rp[ifirst:], sdss_sm10p5_meert15_bulge_dom_wp[ifirst:], color='orange', 
          label=r'bulge-dominated')
__=ax.plot(rp[ifirst:], sdss_sm10p5_mendel13_bulge_dom_wp[ifirst:], '--', color='orange')
__=ax.plot(rp[ifirst:], sdss_sm10p5_mendel13_disk_dom_wp[ifirst:], '--', color='purple')


__=ax.plot(rp[ifirst:], sdss_sm10p5_meert15_disk_dom_wp[ifirst:], color='purple', 
          label=r'disk-dominated')


title = ax.set_title(r'$M_{\ast} > 10^{10.5}M_{\odot}$')
xlabel = ax.set_xlabel(r'$r_{\rm p}$  $[{\rm Mpc}]$')
ylabel = ax.set_ylabel(r'$w_{\rm p}$  $[{\rm Mpc}]$')

leg = ax.legend()
leg.legendHandles[0].set_color('gray')
leg.legendHandles[1].set_color('gray')

# %%
from matplotlib import ticker

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), 
                              sharex=True, sharey=True)

__=ax1.loglog(); __=ax2.loglog()

__=ax1.plot(rp[ifirst:], sdss_sm10p0_meert15_bulge_dom_wp[ifirst:], color='orange', 
          label=r'bulge-dominated: B/T > 3/4')
__=ax1.plot(rp[ifirst:], sdss_sm10p0_mendel13_bulge_dom_wp[ifirst:], '--', color='orange')
__=ax1.plot(rp[ifirst:], sdss_sm10p0_mendel13_disk_dom_wp[ifirst:], '--', color='purple')
__=ax1.plot(rp[ifirst:], sdss_sm10p0_meert15_disk_dom_wp[ifirst:], color='purple', 
          label=r'disk-dominated: B/T < 1/4')


__=ax2.plot(rp[ifirst:], sdss_sm10p5_meert15_bulge_dom_wp[ifirst:], color='orange', 
          label=r'Meert+15')
__=ax2.plot(rp[ifirst:], sdss_sm10p5_mendel13_bulge_dom_wp[ifirst:], '--', color='orange', 
           label=r'Mendel+13')
__=ax2.plot(rp[ifirst:], sdss_sm10p5_mendel13_disk_dom_wp[ifirst:], '--', color='purple')
__=ax2.plot(rp[ifirst:], sdss_sm10p5_meert15_disk_dom_wp[ifirst:], color='purple')


title1 = ax1.set_title(r'$M_{\ast} > 10^{10}M_{\odot}$')
xlabel1 = ax1.set_xlabel(r'$r_{\rm p}$  $[{\rm Mpc}]$')
ylabel1 = ax1.set_ylabel(r'$w_{\rm p}$  $[{\rm Mpc}]$')

title2 = ax2.set_title(r'$M_{\ast} > 10^{10.5}M_{\odot}$')
xlabel2 = ax2.set_xlabel(r'$r_{\rm p}$  $[{\rm Mpc}]$')

leg1 = ax1.legend()
leg2 = ax2.legend()
leg2.legendHandles[0].set_color('k')
leg2.legendHandles[1].set_color('k')

xmin, xmax = 0.1, 30
ymin, ymax = 10, 10000
xlim1 = ax1.set_xlim(xmin, xmax)
xlim2 = ax2.set_xlim(xmin, xmax)
ylim1 = ax1.set_ylim(ymin, ymax)
ylim2 = ax2.set_ylim(ymin, ymax)

ax1.set_xticks((0.1, 0.3, 1, 3, 10, 30))
ax1.get_xaxis().set_major_formatter(ticker.ScalarFormatter())
ax1.get_xaxis().set_minor_formatter(ticker.NullFormatter())
ax2.set_xticks((0.1, 0.3, 1, 3, 10, 30))
ax2.get_xaxis().set_major_formatter(ticker.ScalarFormatter())
ax2.get_xaxis().set_minor_formatter(ticker.NullFormatter())

figname = 'mendel13_vs_meert15_clustering.pdf'
fig.savefig(figname, bbox_extra_artists=[xlabel1, ylabel1], bbox_inches='tight')

# %% [markdown]
# ## Plot clustering trends with size

# %%
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_disk_dom_wp.npy')
sdss_sm10p0_meert15_disk_dom = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_disk_dom_small_wp.npy')
sdss_sm10p0_meert15_disk_dom_small = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_disk_dom_large_wp.npy')
sdss_sm10p0_meert15_disk_dom_large = np.load(_wp_fname)

fig, ax = plt.subplots(1, 1)

__=ax.loglog()

__=ax.plot(rp, sdss_sm10p0_meert15_disk_dom_small, color='green', label='disk-dominated: small')
__=ax.plot(rp, sdss_sm10p0_meert15_disk_dom, color='blue', label='disk-dominated')
__=ax.plot(rp, sdss_sm10p0_meert15_disk_dom_large, color='purple', label='disk-dominated: large')

leg = ax.legend()

# %%
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_bulge_dom_wp.npy')
sdss_sm10p0_meert15_bulge_dom = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_bulge_dom_small_wp.npy')
sdss_sm10p0_meert15_bulge_dom_small = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_meert15_bulge_dom_large_wp.npy')
sdss_sm10p0_meert15_bulge_dom_large = np.load(_wp_fname)

fig, ax = plt.subplots(1, 1)

__=ax.loglog()

__=ax.plot(rp, sdss_sm10p0_meert15_bulge_dom_small, color='red', label='bulge-dominated: small')
__=ax.plot(rp, sdss_sm10p0_meert15_bulge_dom, color='orange', label='bulge-dominated')
__=ax.plot(rp, sdss_sm10p0_meert15_bulge_dom_large, color='gold', label='bulge-dominated: large')

leg = ax.legend()

# %%
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_wp.npy')
sdss_sm10p0_sf = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_small_wp.npy')
sdss_sm10p0_sf_small = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_sf_large_wp.npy')
sdss_sm10p0_sf_large = np.load(_wp_fname)

fig, ax = plt.subplots(1, 1)

__=ax.loglog()

__=ax.plot(rp, sdss_sm10p0_sf_small, color='green', label='star-forming: small')
__=ax.plot(rp, sdss_sm10p0_sf, color='blue', label='star-forming')
__=ax.plot(rp, sdss_sm10p0_sf_large, color='purple', label='star-forming: large')

legend = ax.legend()

# %%
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_wp.npy')
sdss_sm10p0_q = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_small_wp.npy')
sdss_sm10p0_q_small = np.load(_wp_fname)
_wp_fname = os.path.join(wp_dirname, 'sdss_sm10p0_q_large_wp.npy')
sdss_sm10p0_q_large = np.load(_wp_fname)

fig, ax = plt.subplots(1, 1)

__=ax.loglog()

__=ax.plot(rp, sdss_sm10p0_q_small, color='red', label='quenched: small')
__=ax.plot(rp, sdss_sm10p0_q, color='orange', label='quenched')
__=ax.plot(rp, sdss_sm10p0_q_large, color='gold', label='quenched: large')

legend = ax.legend()
